# %%
a=10
b=20
c=a+b
c       #Run--->shift+enter (at a time)(or)other option is also availabe on left top "play button>"

# %%
a=1
b=2
c=a+b
c

# %%
a=100
b=200
c=a+b
c

# %%
a=2
b=4
c=a+b
c

# %%
for i in range(100):
   print(i)      #Is there any interuption go to "square" button click on that ,that stops the problem(and) go to kernel 
                 #also used

# %% [markdown]
# iam learning python

# %% [markdown]
# good morning hyd

# %% [markdown]
# In the jupyter notebook we have two modes
# 1)code:it is used to write a code
#        it has the before cell we saw a []
# 2)markdown mode:it is used to write a story
#           it don't have any type [] and nothing
#
# first we write the code and go to code in that
# we have to click and next click on markdown
# and come to the cell firstly select that and next we do run i.e..,shift+enter

# %%
hello hyd
good morning hey

# %% [markdown]
# # python

# %% [markdown]
# ## python

# %% [markdown]
# ### python

# %% [markdown]
# SHORT cut for "markdown" is"esc+m" then run

# %% [markdown]
# ##### pyton

# %% [markdown]
# compulsery give to the space after the '#' symbol i.e..ex:## python

# %% [markdown]
# codemode to markdown mode shortcut is esc+m
# markdownmode to code mode shortct is esc+y

# %% [markdown]
# - Today i learned how to open jupyter notebook
#
# - Today i learned how to done code
#
# - i learned today create python folder
#
# - from tomorrow onwords i will open my all python notebook
#
# - when kernel is busy  not run another code
#
# - because python kernel is run step by step
#
# - i also learn how to run the code i.e..shift+enter
#
# - i also learn how to run the jupyter notebook
#
# - this is called markdown
#
# - esc+m is the shortcut of the codemode to markdown
#
# - esc+y is the shortcut of the markdown to code

# %% [markdown]
# <img id="dimg_339" src="data:image/png;base64,..." class="YQ4gaf zr758c" height="115" style="object-position:50% 30%" width="437" alt="Python Jupyter Notebooks" data-csiid="zAJ3ZvHSIo321e8PyOrp6QE_32" data-atf="4">

# %% [markdown]
# <img id="dimg_34" src="data:image/jpeg;base64,..." class="YQ4gaf" height="185" style="object-position:center" width="272" alt="Hyderabad (HYD) Airport Lounges Guide ..." data-csiid="ZgN3Zv_mO_Kfvr0P4_mdsQs_18" data-atf="1">

# %% [markdown]
# ### python
#
# ## how to put the image
#
# - Go to google search image ex:hyd
#
# - give right click on, in this we have to see"inspect" option at the last
#
# - then open some code in this we have to see "<img ......"
#
# - give right click on it and next open other box  in that
#
# - we choose "edit as html" click on it
#
# - and next select all(ctrl+a) and copy(ctrl+c)
#
# - come to jupyter notebook paste(ctrl+v) it
#
# - markdown it i.e..(esc+m) and run i.e..shift+enter
#
# - Finally we see the image

# %% [markdown]
# <img id="dimg_143" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSbYtmi_iZ-23kHwgLV4cwtt0pfdW7UB0YUuw&amp;s" class="YQ4gaf" height="168" style="object-position:72% 16%" width="299" alt="7 Top Jobs in Data Science that Every ..." data-csiid="SAZ3Zo_oCcfD1e8Pv9i9mQ0_213" data-atf="4" data-ilt="1719033218546" data-deferred="3">

# %% [markdown]
# <img id="dimg_375" src="data:image/jpeg;base64,..." class="YQ4gaf" height="224" style="object-position:76% 50%" width="225" alt="Nature is a beautiful thing" data-csiid="Bgd3ZqKPFO-_vr0Pn5Xl6Qs_33" data-atf="1">
